# %%
class Book:
    def __init__(self, title, author, rate):
        self.title = title
        self.author = author
        self.rate = rate   # goes through the setter now

    @property
    def rate(self):
        return self.__rate

    @rate.setter
    def rate(self, rate):
        if rate < 0:
            return 'not a valid rate'
        else:
            self.__rate = rate


class Ebook(Book):
    def __init__(self, title, author, rate, file_size):
        super().__init__(title, author, rate)
        self.file_size = file_size


e1 = Ebook('The tale of christmas', 'Anukrit', 78, 10.5)
e2 = Ebook('The tale of Ammakalam vinay', 'Aditya', -9, 20.3)

print(e1.author, e1.title, e1.rate, e1.file_size)
print(e2.author, e2.title, e2.rate, e2.file_size)
# Out:
# Anukrit The tale of christmas 78 10.5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 29
#      26 e2 = Ebook('The tale of Ammakalam vinay', 'Aditya', -9, 20.3)
#      28 print(e1.author, e1.title, e1.rate, e1.file_size)
# ---> 29 print(e2.author, e2.title, e2.rate, e2.file_size)
#
# Cell In[9], line 9, in Book.rate(self)
#       7 @property
#       8 def rate(self):
# ----> 9     return self.__rate
#
# AttributeError: 'Ebook' object has no attribute '_Book__rate'

# %%
class Product:

    def __init__(self , name , price = None) -> None:
        self.name = name
        self.__price = price

    
    def get_price(self):
        return self.__price
    

    def set_price(self , price):
        if price < 0:
            print("price cant be negative pls change the price value")
        
        else:
            self.__price = price


p1 = Product('Asprin')
p1.set_price(-10)
p2 = Product('Gamma')
p2.set_price(50)

print(p1.get_price())
print(p2.get_price())
# Out:
# price cant be negative pls change the price value
# None
# 50
