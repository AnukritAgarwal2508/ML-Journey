# %%
import urllib.request
import urllib.error
import urllib.parse

url = "https://chatgpt.com/c/6a753628-43ac-83e8-baea-798e94d34b33"
pieces = urllib.parse.urlparse(url)
print(pieces.scheme)
print(pieces.netloc)
print(pieces.path)
print(pieces.query)


response = urllib.request.urlopen("https://www.google.com/")
print(response.status)


content = response.read()
print(content[:100])

try:
    urllib.request.urlopen("https://www.google.com/")

except urllib.error.URLError as e:
    print("Something went wrong: ",e.reason)
# Out:
# https
# chatgpt.com
# /c/6a753628-43ac-83e8-baea-798e94d34b33
#
# 200
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-AU"><head><meta cont'
