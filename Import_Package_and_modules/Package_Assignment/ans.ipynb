# %%
from math import sqrt,sinh

print(sqrt(25))
print(sinh(90))
# Out:
# 5.0
# 6.102016471589204e+38

# %%
import datetime as dt 

now = dt.datetime.now()
print(now)
# Out:
# 2026-07-19 16:24:42.252927

# %%
from random import randint

print(randint(1,100))
# Out:
# 7

# %%
from math import pow,sqrt

print(sqrt(25))
print(pow(2,3))
# Out:
# 5.0
# 8.0

# %%
''' error handling question will look into it further'''

# %%
import os

# os.mkdir('new_folder')
# os.listdir('new_folder')
# os.rmdir('new_folder')

# %%
''' dont know the sys module yet to learn'''

# %%
from math import *

print(factorial(23))
print(gcd(90,12))
# Out:
# 25852016738884976640000
# 6

# %%
import datetime as dt

now = dt.datetime.now()
print(now)
print(now.day)

future = now + dt.timedelta(days = 180)
print(future)
# Out:
# 2026-07-19 16:32:08.800819
# 19
# 2027-01-15 16:32:08.800819

# %%
from My_Package.module1 import addition
from My_Package.module2 import multiple

print(addition(2 , 3))
print(multiple(2 , 3))
# Out:
# 5
# 6

# %%
import shutil

shutil.move('__init__.py','Package_Assignment/My_Package')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/shutil.py:856, in move(src, dst, copy_function)
#     855 try:
# --> 856     os.rename(src, real_dst)
#     857 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '__init__.py' -> 'Package_Assignment/My_Package'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 import shutil
# ----> 3 shutil.move('__init__.py','Package_Assignment/My_Package')
#
# File /opt/anaconda3/lib/python3.13/shutil.py:876, in move(src, dst, copy_function)
#     874         rmtree(src)
#     875     else:
# --> 876         copy_function(src, real_dst)
#     877         os.unlink(src)
#     878 return real_dst
#
# ...

# %%
from My_Package import *

print(addition(2 , 3))
print(multiple(2 , 3))
# Out:
# 5
# 6
