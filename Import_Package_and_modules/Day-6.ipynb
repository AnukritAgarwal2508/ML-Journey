# %%
'''inside this there are lot of functions'''
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi

print(sqrt(16))
print(sqrt(25))

print(pi)
# Out:
# 3.141592653589793

# %%
''' np here is an alias'''
import numpy as np

np.array([1,2,3,5])
# Out:
# array([1, 2, 3, 5])

# %%
#import every function from math
from math import *

print(sqrt(16))
print(pi)
# Out:
# 2.0
# 3.141592653589793

# %%
from Package.maths import addition

addition(2,3)
# Out:
# 5

# %%
from Package import maths

maths.addition(2,3)
# Out:
# 5

# %%
import array

arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math

math.sqrt(4)
math.pi
# Out:
# 3.141592653589793

# %%
import random

print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 7
# banana

# %%
###os

import os

print(os.getcwd())
# Out:
# /Users/anukrit/Desktop/ML Journey/Import_Package_and_modules

# %%
os.mkdir('test.dir')

# %%
## high level operation on files and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
#DATA SERIALIZATION 
import json
new_dict = {
    'A' : 'a',
    'B' : 'b',
    'C' : 'c'
}

json_str = json.dumps(new_dict)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"A": "a", "B": "b", "C": "c"}
# <class 'str'>
# {'A': 'a', 'B': 'b', 'C': 'c'}
# <class 'dict'>

# %%
## csv

import csv

with open('example.csv',mode = 'w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Krish', 21])

with open('example.csv',mode = 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Krish', '21']

# %%
## datetime

from datetime import datetime,timedelta

now = datetime.now()
print(now)


yesterday = now - timedelta(days = 1)
print(yesterday)
# Out:
# 2026-07-18 23:17:07.501808
# 2026-07-17 23:17:07.501808

# %%
##time 

import time 

print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1784396881.439994
# 1784396883.4459488

# %%
import re

pattern = r'\d+'
text = "There are 123 apples 456"

match = re.search(pattern,text)
print(match.group())
# Out:
# 123
